# %% [markdown]
# ## Operators#### 1. Arithmetic Operators: +, -, *, /, // (floor division), % (modulo), ** (exponentiation)#### 2. Comparison Operators: ==, !=, >, <, >=, <=#### 3. Logical Operators: and, or, not#### 4. Assignment Operators: =, +=, -=, *=, /=, //=, %=, **=#### 5. Bitwise Operators: &, |, ^ (xor), ~ (bitwise negation), << (left shift), >> (right shift)#### 6. Membership Operators: in, not in#### 7. Identity Operators: is, is not

# %% [markdown]
# ## Arithmetic Operators

# %%
# Arithmetic operatorsx = 10y = 3print(x + y)  # Output: 13
# Out:
# 13

# %%
x = 10y = 3print(x - y)  # Output: 7
# Out:
# 7

# %%
x = 10y = 5print(x / y)  # Output: 2.0
# Out:
# 2.0

# %%
x = 10y = 3print(x * y)  # Output: 30
# Out:
# 30

# %%
x = 10y = 3print(x // y)  # Output: 3
# Out:
# 3

# %%
x = 10y = 3print(x % y)  # Output: 1
# Out:
# 1

# %%
x = 10y = 3print(x ** y)  # Output: 1000
# Out:
# 1000

# %% [markdown]
# ## Comparison Operators

# %%
x = 20y = 15

# %%
print(x > y)  # Output: True
# Out:
# True

# %%
print(x < y)  # Output: False
# Out:
# False

# %%
print(x >= y)  # Output: True
# Out:
# True

# %%
print(x <= y)  # Output: False
# Out:
# False

# %%
print(x == y)  # Output: False
# Out:
# False

# %%
print(x != y)  # Output: True
# Out:
# True

# %% [markdown]
# ## Logical Operators

# %%
x = 9y = 10

# %%
print(x > 5 and y < 5)  # Output: False
# Out:
# False

# %%
print(x > 5 or y < 5)  # Output: True
# Out:
# True

# %%
print(not(x > 6))  # Output: False
# Out:
# False

# %% [markdown]
# ## Assignment Operators

# %%
x = 10

# %%
x += 1print(x)  # Output: 11
# Out:
# 11

# %%
x -= 2print(x)  # Output: 9
# Out:
# 9

# %%
x *= 3print(x)  # Output: 27
# Out:
# 27

# %%
x /= 4print(x)  # Output: 6.75
# Out:
# 6.75

# %%
x //= 2print(x)  # Output: 3.0
# Out:
# 3.0

# %%
x = 2x %= 2print(x)  # Output: 0
# Out:
# 0

# %%
x = 5x **= 3print(x)  # Output: 125
# Out:
# 125

# %% [markdown]
# ## Bitwise Operators

# %%
x = 10y = 3

# %%
print(x & y)  # Output: 2
# Out:
# 2

# %%
print(x | y)  # Output: 11
# Out:
# 11

# %%
#(xor)print(x ^ y)  # Output: 9
# Out:
# 9

# %%
#(bitwise negation)print(~x)  # Output: -11
# Out:
# -11

# %%
#(left shift)print(x >> 2)  # Output: 2
# Out:
# 2

# %%
#(right shift)print(x << 3)  # Output: 80
# Out:
# 80

# %% [markdown]
# ## Membership Operators

# %%
a = [1,2,3,4,5]

# %%
print( 2 in a)
# Out:
# True

# %%
print( 4 not in a)
# Out:
# False

# %% [markdown]
# ## Identity Operators

# %%
a = [1,2,3,4,5]b = [1,2,3,4,5]

# %%
print( a is b)
# Out:
# False

# %%
print( a is not b)
# Out:
# True
