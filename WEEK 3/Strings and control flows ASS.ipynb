# %%
Name_= "ParoCyber LLC"

# %%
Name_
# Out:
# 'ParoCyber LLC'

# %%
#Modyfying into upper case

# %%
#upper case()
Name_= Name_.upper()
Name_
# Out:
# 'PAROCYBER LLC'

# %%
#lower case()
Name_=Name_.lower()
Name_
# Out:
# 'parocyber llc'

# %%
# isalpha
Name_= Name_.isalpha()
Name_
# Out:
# False

# %%
# isdigit()
Name_= Name_.isdigit()
print(Name_)
# Out:
# False

# %%
#islower
Name_= Name_.islower()
Name_
# Out:
# False

# %%
#isupper
Name_= Name_.isupper()
Name_
# Out:
# True

# %%
# How to split strings

# %%
#split()
Flowers = "Last week the singles did'nt get flowers"
Flowers.split(" ")
# Out:
# ['Last', 'week', 'the', 'singles', "did'nt", 'get', 'flowers']

# %%
word = Flowers.split(" ")
print("_".join(word))
# Out:
# Last_week_the_singles_did'nt_get_flowers

# %%
#replace()
Flowers= "Last week the singles didn't get flowers"
word = Flowers.replace("singles","men")
print(word)
# Out:
# Last week the men didn't get flowers

# %%
#startswith()
Flower = "roses"
Flower.startswith("s")
# Out:
# False

# %%
Flower.startswith("r")
# Out:
# True

# %%
# endswith
Flower2 ="sunflower"
Flower2.endswith("t")
# Out:
# False

# %%
Flower2.endswith("r")
# Out:
# True
