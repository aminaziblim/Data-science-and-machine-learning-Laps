# %%
X = 10
Y = 15
X + Y
# Out:
# 25

# %%
# subtraction
Y - X
# Out:
# 5

# %%
#mulitplication
X * Y
# Out:
# 150

# %%
#division
X = 300
Y = 6
X / Y
# Out:
# 50.0

# %%
# floor division
X = 300
Y = 7
X // 7
# Out:
# 42

# %%
#modulo
X = 300
Y = 7
X % Y
# Out:
# 6

# %%
#exponential
X = 5
Y = 3
X**3
# Out:
# 125

# %%
#C0MPARISON OPERATOR

# %%
# greater than
X = 54
Y = 77
X > Y
# Out:
# False

# %%
#less than
X = 54
Y = 77
X < Y
# Out:
# True

# %%
#equal to
X == Y
# Out:
# False

# %%
#greater than or equal to
X >= Y
# Out:
# False

# %%
#less than or equal to
X <= Y
# Out:
# True

# %%
#not equal to
X != Y
# Out:
# True

# %%
# LOGICAL OPERATORS

# %%
# and
X = 32
Y = 21
X < 30 and Y < 25
# Out:
# False

# %%
# or
X < 30 or Y < 25
# Out:
# True

# %%
# not
not(X < 32)
# Out:
# True

# %%
# ASSIGNMENT OPERATOR

# %%
X = 55

# %%
X
# Out:
# 55

# %%
X +=23

# %%
X
# Out:
# 78

# %%
X-=23

# %%
X
# Out:
# 55

# %%
X *=23

# %%
X
# Out:
# 1265

# %%
X /=23

# %%
X
# Out:
# 55.0

# %%
#BITWISE OPERATION

# %%
#AND(&), OR(|),(^)(~)(<<)(>>)

# %%
X = 10
Y = 3
X & Y
# Out:
# 2

# %%
X|Y
# Out:
# 11

# %%
X ^ Y
# Out:
# 9

# %%
~X
# Out:
# -11

# %%
~Y
# Out:
# -4

# %%
X >> 2
# Out:
# 2

# %%
X << 2
# Out:
# 40
